# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
collision_data = pd.read_csv('collisions.csv', parse_dates=['timestamp'])

def visualize_collisions(time_range='H'):
    grouped_data = collision_data.set_index('timestamp').groupby(pd.Grouper(freq=time_range)).size()

    plt.figure(figsize=(10, 6))
    grouped_data.plot(kind='bar')
    plt.title(f'Collisions Grouped by {time_range}')
    plt.xlabel('Time')
    plt.ylabel('Number of Collisions')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

visualize_collisions('5S')
# Out:
# /var/folders/42/hxfkjkhn0r1fyf_4lqcvd58c0000gn/T/ipykernel_27110/2351529081.py:4: FutureWarning: 'S' is deprecated and will be removed in a future version, please use 's' instead.
#   grouped_data = collision_data.set_index('timestamp').groupby(pd.Grouper(freq=time_range)).size()
